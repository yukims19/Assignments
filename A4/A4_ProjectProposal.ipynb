# %% [markdown]
# # COGS 108 - Assignment 4: Project Proposal

# %% [markdown]
# ## Important
#
# - ONE, and only one, member of your group should upload this notebook to TritonED.
# - Each member of the group will receieve the same grade on this assignment.
# - Keep the file name the same: submit the file 'A4_ProjectProposal.ipynb'

# %% [markdown]
# ## Overview

# %% [markdown]
# Read the project description, and detailed instructions for this assignment, in A4_ProjectOutlineAndProposal.pdf.

# %% [markdown]
# ## Group Members: Fill in the Student ID's of each group member here
# - A########
# - A########
# - A########

# %% [markdown]
# ### Research Question
#
# What is your research question? (1-2 sentences)

# %% [markdown]
# *Fill in your research question here*

# %% [markdown]
# ### Hypothesis
#
# What is your prediction (2-3 sentences)

# %% [markdown]
# *Fill in your hypotheses here*

# %% [markdown]
# ### Dataset(s)
#
# What data will you use to answer your question? Describe the dataset in terms of number of observations, number of features, etc. You must use at least one dataset containing at least approximately 1000 observations (if your data are smaller but you feel they are sufficient, email Prof. Voytek). You are welcome (and in fact recommended) to find multiple datasets! If you do so, describe each one, and briefly explain how you will combine them together.

# %% [markdown]
# *Fill in your dataset information here*
#
# (Copy this information for each dataset)
# - Dataset Name:
# - Link to the dataset:
# - Number of observations:
#
# 1-2 sentences describing the dataset.
#
# If you plan to use multiple datasets, add 1-2 sentences about how you plan to combine these datasets.

# %% [markdown]
# ### Background & Prior Work
#
# Why is this question of interest, what background information led you to your hypothesis, and why is this important?
#
# Find some relevant prior work, and reference them. Even if you think you have a totally novel question, find the most similar prior work you can, and discuss how it relates to your project.
#
# References can be research publications, but they need not be: blogs, github repositories, company websites, etc., are viable references if they are relevant to your project.
#
# (2-3 paragraphs, including at least 2 references)

# %% [markdown]
# *Fill in your background and prior work here*
#
# Refs (include a link):
# - 1)
# - 2)

# %% [markdown]
# ### Proposed Methods
#
# What methods will you use to analyze your data?
#
# - How 'clean' is the data? To the extent that it requires cleaning, how will you do so?
# - ANALYSIS
# - Include a list of packages you expect to use for you project. If you plan to use packages we have not used in class, add a very brief description ()
#
# (1-2 paragraphs)

# %% [markdown]
# *Fill in your proposed methods information here*

# %% [markdown]
# ### Discussion
#
# What are the pitfalls and potential confounds of your data and/or methods? For example, how might biases in your data sources or analyses influence your interpretations? What will you do if you methods don't work and/or your hypotheses are wrong?
#
# (2-3 paragraphs)

# %% [markdown]
# *Fill in your discussion information here*
